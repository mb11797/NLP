# %%
# TF : Term Frequency - which means how frequently a term occurs in a document
# IDF : Inverse Document Frequency - which measures how important a term is.

from sklearn.datasets import fetch_20newsgroups

# %%
category_map = {'misc.forsale' : 'Sales',
                'rec.motorcycles' : 'Motorcycles',
                'rec.sport.baseball' : 'Baseball',
                'sci.crypt' : 'Cryptography',
                'sci.space' : 'Space'
               }
training_data = fetch_20newsgroups(subset = 'train', categories = category_map.keys())

# %%
training_data.keys()
# Out:
# dict_keys(['data', 'filenames', 'target_names', 'target', 'DESCR', 'description'])

# %%
print(len(training_data['data']))
# Out:
# 2968

# %%
print(training_data['data'])
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print(training_data['target_names'])
# Out:
# ['misc.forsale', 'rec.motorcycles', 'rec.sport.baseball', 'sci.crypt', 'sci.space']

# %%
print(training_data['target'])
# Out:
# [2 2 2 ... 2 4 4]

# %%
print(len(training_data['target']))
# Out:
# 2968

# %%
print(training_data['target'][:50])
# Out:
# [2 2 2 4 2 4 2 2 1 0 3 4 2 1 0 1 3 4 2 0 1 4 3 1 1 0 0 1 2 1 0 3 1 4 3 4 2
#  2 3 4 4 2 1 3 4 0 1 3 4 2]

# %%
print(training_data['data'][0])
# Out:
# From: jbragg@morgan.ucs.mun.ca (James Bragg)
# Subject: Re: NL Stats
# Organization: Memorial University of Newfoundland
# Lines: 9
#
#
# Doug, those stats are great!  they help immensely.  I tried to E-Mail
# you with some comments on them but my mail server does not recognize
# your address.  Could you E-Mail me with some info on how to get E-Mail
# to you?  Thanks!
#
# Jim Bragg
# (jbragg@morgan.ucs.mun.ca)

# %%
print(len(training_data['filenames']))
# Out:
# 2968

# %%
print(training_data['filenames'])
# Out:
# ['C:\\Users\\mbman\\scikit_learn_data\\20news_home\\20news-bydate-train\\rec.sport.baseball\\104534'
#  'C:\\Users\\mbman\\scikit_learn_data\\20news_home\\20news-bydate-train\\rec.sport.baseball\\104443'
#  'C:\\Users\\mbman\\scikit_learn_data\\20news_home\\20news-bydate-train\\rec.sport.baseball\\102696'
#  ...
#  'C:\\Users\\mbman\\scikit_learn_data\\20news_home\\20news-bydate-train\\rec.sport.baseball\\104903'
#  'C:\\Users\\mbman\\scikit_learn_data\\20news_home\\20news-bydate-train\\sci.space\\61141'
#  'C:\\Users\\mbman\\scikit_learn_data\\20news_home\\20news-bydate-train\\sci.space\\60934']

# %%
print(training_data['filenames'][:2])
# Out:
# ['C:\\Users\\mbman\\scikit_learn_data\\20news_home\\20news-bydate-train\\rec.sport.baseball\\104534'
#  'C:\\Users\\mbman\\scikit_learn_data\\20news_home\\20news-bydate-train\\rec.sport.baseball\\104443']

# %%
print(len(training_data['description']))
# Out:
# 33

# %%
print(training_data['description'])
# Out:
# the 20 newsgroups by date dataset

# %%
print(training_data['DESCR'])
# Out:
# None

# %%
type(training_data['DESCR'])
# Out:
# NoneType

# %%
print(training_data.target_names)
# Out:
# ['misc.forsale', 'rec.motorcycles', 'rec.sport.baseball', 'sci.crypt', 'sci.space']

# %%
type(training_data)
# Out:
# sklearn.utils.Bunch

# %%
from sklearn.feature_extraction.text import CountVectorizer

vect = CountVectorizer()

x_train_termcounts = vect.fit_transform(training_data.data)

print('Dimensions of training data : ',x_train_termcounts.shape)
# Out:
# Dimensions of training data :  (2968, 40605)

# %%
type(x_train_termcounts)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
print(x_train_termcounts[0])
# Out:
#   (0, 22137)	1
#   (0, 36519)	1
#   (0, 18586)	1
#   (0, 20332)	1
#   (0, 21160)	1
#   (0, 25043)	1
#   (0, 12872)	1
#   (0, 6542)	1
#   (0, 40394)	1
#   (0, 31072)	1
#   (0, 27119)	1
#   (0, 14971)	1
#   (0, 33314)	1
#   (0, 26352)	1
#   (0, 10155)	1
#   (0, 36548)	1
#   (0, 27636)	2
#   (0, 12039)	1
#   (0, 34315)	2
#   (0, 39830)	2
#   (0, 40386)	3
#   (0, 24463)	4
#   (0, 36916)	3
#   (0, 37330)	1
#   (0, 20826)	1
#   (0, 19830)	1
#   (0, 36595)	1
#   (0, 19049)	1
#   (0, 7719)	1
#   (0, 36662)	1
#   (0, 15095)	1
#   (0, 23805)	1
#   (0, 26778)	1
#   (0, 27493)	1
#   (0, 38081)	1
#   (0, 25183)	1
#   (0, 27820)	1
#   (0, 35015)	2
#   (0, 26972)	1
#   (0, 30924)	1
#   (0, 35433)	1
#   (0, 9700)	2
#   (0, 21909)	1
#   (0, 10452)	2
#   (0, 26259)	2
#   (0, 37699)	2
#   (0, 25961)	2
#   (0, 21985)	2
#   (0, 18028)	1

# %%
training_data.target
# Out:
# array([2, 2, 2, ..., 2, 4, 4], dtype=int64)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfTransformer

# %%
input_data = ["The one holds a bat and another holds a ball",
              "I was riding my bike on mountain",
              "ISRO is helping India to reach Mars"
             ]

# %%
tfidf = TfidfTransformer()
x_train_tfidf = tfidf.fit_transform(x_train_termcounts)

classifier = MultinomialNB()
classifier.fit(x_train_tfidf, training_data.target)

x_input_termcounts = vect.transform(input_data)             #?????????????
x_input_tfidf = tfidf.transform(x_input_termcounts)         #?????????????

# %%
predicted_categories = classifier.predict(x_input_tfidf)

# %%
print(predicted_categories)
# Out:
# [2 1 4]

# %%
for sentence, category in zip(input_data,predicted_categories):
    print("\n Input : ",sentence, "\nPredicted Category : ",category_map[training_data.target_names[category]])
# Out:
#  Input :  The one holds a bat and another holds a ball
# Predicted Category :  Baseball
#
#  Input :  I was riding my bike on mountain
# Predicted Category :  Motorcycles
#
#  Input :  ISRO is helping India to reach Mars
# Predicted Category :  Space

# %%
ip = zip(input_data,predicted_categories)

# %%
print(list(ip))
# Out:
# [('The one holds a bat and another holds a ball', 2), ('I was riding my bike on mountain', 1), ('ISRO is helping India to reach Mars', 4)]

# %%
testing_data = fetch_20newsgroups(subset = 'test',categories = category_map.keys())

# %%
len(testing_data)
# Out:
# 6

# %%
print(testing_data.keys())
# Out:
# dict_keys(['data', 'filenames', 'target_names', 'target', 'DESCR', 'description'])

# %%
len(testing_data.target)
# Out:
# 1975

# %%
testing_data['data'][:1975]
# Out:
# ["From: gaijin@ale.Japan.Sun.COM (John Little - Nihon Sun Repair Depot)\nSubject: Personal Problems   (Was - Re: So, do any police ossifers read ...)\nOrganization: Nihon Sun Microsystems - Atsugi Technical Centre - JAPAN.\nLines: 12\nNNTP-Posting-Host: ale.japan.sun.com\n\nIn article <ltgnt9INNfpq@earth.cs.utexas.edu> mcguire@cs.utexas.edu \\\n(Tommy Marcus McGuire) writes:\n%\n% I can't haul my big dic. around on my bike...\n%\n\n   ...or is it a boast?\n\n-- \n   ------------------------------------------------------------------------\n  | John Little  - gaijin@Japan.Sun.COM  - Sun Microsystems. Atsugi, Japan | \n   ------------------------------------------------------------------------\n",
# ...

# %%
testing_data['target'][:]
# Out:
# array([1, 3, 0, ..., 2, 0, 4], dtype=int64)

# %%
test_data = vect.fit_transform(testing_data.data)

# %%
test_data.shape
# Out:
# (1975, 28277)

# %%
tfidf_test = tfidf.fit_transform(test_data)

# %%
tfidf_test.shape
# Out:
# (1975, 28277)

# %%
x_input_tfidf.shape
# Out:
# (3, 40605)

# %%
test_x = testing_data.data
test_y = testing_data.target

# %%
len(test_x)
# Out:
# 1975

# %%
len(test_y)
# Out:
# 1975

# %%
import numpy as np

# %%
test_x.pop()
# Out:
# 'Subject: Re: Math?? (Was US govt & Technolgy Investment\nFrom: kubo@zariski.harvard.edu (Tal Kubo)\nOrganization: Dept. of Math, Harvard Univ.\nKeywords: science?\nNntp-Posting-Host: zariski.harvard.edu\nLines: 14\n\n\n>greg mccolm suggested that math is a good example of the inertia\n>(silver age) of current science.....\n>\n>is math really a science? what new has math "told" us recently?\n>please dont flame me... ive taken no math since 11th grade...\n>completed BC calc early and go the hell out... is there really\n>NEW stuff going on?? (im not flaming, but honestly durious...)\n\n\nNope.  We\'re just living off the inheritance from our forefathers,\nreading dusty old books, and exchanging baroque incantations among\na small circle of devotees.\n\n'

# %%
test_x = np.reshape(test_x, (-1,2))

# %%
# from nltk.classify import NaiveBayesClassifier

# classifier_2 = NaiveBayesClassifier.train(x)
# print("Accuracy :",nltk.classify.accuracy(classifier_2,test_x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-117-41bc9cca2bae> in <module>()
#       1 from nltk.classify import NaiveBayesClassifier
#       2
# ----> 3 classifier_2 = NaiveBayesClassifier.train(x)
#       4 print("Accuracy :",nltk.classify.accuracy(classifier_2,test_x))
#
# NameError: name 'x' is not defined
